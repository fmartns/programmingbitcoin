# %%
############## PLEASE RUN THIS CELL FIRST! ###################

# import everything and define a test runner function
from importlib import reload
from helper import run
import op
import script

# %% [markdown]
# ### Exercise 1
#
# Write the `op_hash160` function.
#
# #### Make [this test](/edit/code-ch06/op.py) pass: `op.py:OpTest:test_op_hash160`

# %%
# Exercise 1

reload(op)

def op_hash160(stack):
    if len(stack) < 1:
        return False
    element = stack.pop()
    stack.append(op.hash160(element))
    return True

op.op_hash160 = op_hash160

run(op.OpTest("test_op_hash160"))
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %%
from script import Script
z = 0x7c076ff316692a3d7eb3c3bb0f8b1488cf72e1afcd929e29307032997a838a3d
sec = bytes.fromhex('04887387e452b8eacc4acfde10d9aaf7f6d9a0f975aabb10d006e4da568744d06c61de6d95231cd89026e286df3b6ae4a894a3378e393e93a0f45b666329a0ae34')
sig = bytes.fromhex('3045022000eff69ef2b1bd93a66ed5219add4fb51e11a840f404876325a1e8ffe0529a2c022100c7207fee197d27c618aea621406f6bf5ef6fca38681d82b2f06fddbdce6feab601')
script_pubkey = Script([sec, 0xac])
script_sig = Script([sig])
combined_script = script_sig + script_pubkey
print(combined_script.evaluate(z))
# Out:
# False

# %% [markdown]
# ### Exercise 2
#
# Write the `op_checksig` function in `op.py`
#
# #### Make [this test](/edit/code-ch06/op.py) pass: `op.py:OpTest:test_op_checksig`

# %%
# Exercise 2

reload(op)
run(op.OpTest("test_op_checksig"))
# Out:
# F
# ======================================================================
# FAIL: test_op_checksig (op.OpTest.test_op_checksig)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/fmartns/Documents/programmingbitcoin/code-ch06/op.py", line 753, in test_op_checksig
#     self.assertTrue(op_checksig(stack, z))
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: None is not true
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.095s
#
# FAILED (failures=1)

# %% [markdown]
# ### Exercise 3
#
# Create a ScriptSig that can unlock this ScriptPubKey. Note `OP_MUL` multiplies the top two elements of the stack.
#
# `767695935687`
#
# * `56 = OP_6`
# * `76 = OP_DUP`
# * `87 = OP_EQUAL`
# * `93 = OP_ADD`
# * `95 = OP_MUL`

# %%
# Exercise 3

from script import Script

script_pubkey = Script([0x76, 0x76, 0x95, 0x93, 0x56, 0x87])
script_sig = Script([])  # FILL THIS IN
combined_script = script_sig + script_pubkey
print(combined_script.evaluate(0))

# %% [markdown]
# ### Exercise 4
#
# Figure out what this Script is doing:
#
# `6e879169a77ca787`
#
# * `69 = OP_VERIFY`
# * `6e = OP_2DUP`
# * `7c = OP_SWAP`
# * `87 = OP_EQUAL`
# * `91 = OP_NOT`
# * `a7 = OP_SHA1`
#
# Use the `Script.parse` method and look up what various opcodes do at https://en.bitcoin.it/wiki/Script

# %%
# Exercise 4

from script import Script

script_pubkey = Script([0x6e, 0x87, 0x91, 0x69, 0xa7, 0x7c, 0xa7, 0x87])
script_sig = Script([])  # FILL THIS IN
combined_script = script_sig + script_pubkey
print(combined_script.evaluate(0))
